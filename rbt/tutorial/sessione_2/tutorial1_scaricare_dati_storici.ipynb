# %% [markdown]
# # API

# %%
# INIT
import requests

# %% [markdown]
# ## Binance
# [Binance GitHub Doc](https://github.com/binance/binance-spot-api-docs/blob/master/rest-api.md)

# %%
base_url = 'https://api.binance.com'

# %%
path1   = '/api/v3/exchangeInfo'
r1      = requests.get(base_url+path1)
r1.json()

# %%
path2   = '/api/v3/klines'
params2 = '?symbol=BTCUSDC&interval=1m'
r2      = requests.get(base_url+path2+params2) # or requests.get(base_url+path2,params={'symbol':'BTCUSDC','interval':'1m'})
r2.json() # Candle info

# %% [markdown]
# ## Kucoin
# [Kucoin Doc](https://docs.kucoin.com/#base-url)

# %%
base_url = 'https://api.kucoin.com'
path3 = '/api/v1/market/histories/'
params3 = '?symbol=BTC-USDC'
r3      = requests.get(base_url+path3+params3)
r3.json()
# Out:
# {'code': '200000',
#  'data': [{'sequence': '1614275902985',
#    'price': '45873.1',
#    'size': '0.05551596',
#    'side': 'buy',
#    'time': 1649190537346227244},
#   {'sequence': '1614275902996',
#    'price': '45873.1',
#    'size': '0.04594137',
#    'side': 'buy',
#    'time': 1649190537385343322},
#   {'sequence': '1614275903001',
#    'price': '45873.1',
#    'size': '0.05167005',
#    'side': 'buy',
#    'time': 1649190537427080359},
#   {'sequence': '1614275903006',
#    'price': '45873.1',
#    'size': '0.05883135',
#    'side': 'buy',
#    'time': 1649190537448752834},
#   {'sequence': '1614275903009',
#    'price': '45873.1',
#    'size': '0.05420588',
#    'side': 'buy',
#    'time': 1649190537448938024},
#   {'sequence': '1614275903020',
#    'price': '45875.3',
#    'size': '0.04583014',
#    'side': 'buy',
#    'time': 1649190537512926154},
#   {'sequence': '1614275903024',
#    'price': '45875.3',
#    'size': '0.06542089',
#    'side': 'buy',
#    'time': 1649190537555245868},
#   {'sequence': '1614275903029',
#    'price': '45875.3',
#    'size': '0.06542089',
#    'side': 'buy',
#    'time': 1649190537566285928},
#   {'sequence': '1614275903143',
#    'price': '45874.8',
#    'size': '0.02531903',
#    'side': 'sell',
#    'time': 1649190541062263933},
#   {'sequence': '1614275903146',
#    'price': '45874.8',
#    'size': '0.02348218',
#    'side': 'sell',
#    'time': 1649190541104501330},
#   {'sequence': '1614275903150',
#    'price': '45874.8',
#    'size': '0.02348218',
#    'side': 'sell',
#    'time': 1649190541126084087},
#   {'sequence': '1614275903153',
#    'price': '45874.8',
#    'size': '0.00552968',
#    'side': 'sell',
#    'time': 1649190541126280875},
#   {'sequence': '1614275903159',
#    'price': '45874.8',
#    'size': '0.02062176',
#    'side': 'sell',
#    'time': 1649190541158143072},
#   {'sequence': '1614275903163',
#    'price': '45874.8',
#    'size': '0.02062176',
#    'side': 'sell',
#    'time': 1649190541179809101},
#   {'sequence': '1614275903170',
#    'price': '45874.8',
#    'size': '0.02062176',
#    'side': 'sell',
#    'time': 1649190541211920902},
#   {'sequence': '1614275903173',
#    'price': '45874.8',
#    'size': '0.02062176',
#    'side': 'sell',
#    'time': 1649190541212136381},
#   {'sequence': '1614275903176',
#    'price': '45874.8',
#    'size': '0.02985114',
#    'side': 'sell',
#    'time': 1649190541212207930},
#   {'sequence': '1614275903183',
#    'price': '45874.8',
#    'size': '0.02985114',
#    'side': 'sell',
#    'time': 1649190541274962755},
#   {'sequence': '1614275903670',
#    'price': '45868.6',
#    'size': '0.02474631',
#    'side': 'buy',
#    'time': 1649190563672379749},
#   {'sequence': '1614275903673',
#    'price': '45868.6',
#    'size': '0.02474631',
#    'side': 'buy',
#    'time': 1649190563683166610},
#   {'sequence': '1614275903676',
#    'price': '45868.6',
#    'size': '0.00805692',
#    'side': 'buy',
#    'time': 1649190563704720808},
#   {'sequence': '1614275903689',
#    'price': '45871.1',
#    'size': '0.03065388',
#    'side': 'buy',
#    'time': 1649190563758473706},
#   {'sequence': '1614275903708',
#    'price': '45868',
#    'size': '0.02525999',
#    'side': 'buy',
#    'time': 1649190563872946794},
#   {'sequence': '1614275903713',
#    'price': '45868',
#    'size': '0.00307648',
#    'side': 'buy',
#    'time': 1649190563913794602},
#   {'sequence': '1614275904135',
#    'price': '45878.3',
#    'size': '0.01991803',
#    'side': 'sell',
#    'time': 1649190594894441978},
#   {'sequence': '1614275904141',
#    'price': '45878.3',
#    'size': '0.02468604',
#    'side': 'sell',
#    'time': 1649190594948343959},
#   {'sequence': '1614275904144',
#    'price': '45878.3',
#    'size': '0.02468604',
#    'side': 'sell',
#    'time': 1649190594948516863},
#   {'sequence': '1614275904147',
#    'price': '45878.3',
#    'size': '0.02468604',
#    'side': 'sell',
#    'time': 1649190594948585185},
#   {'sequence': '1614275904152',
#    'price': '45878.3',
#    'size': '0.00630336',
#    'side': 'sell',
#    'time': 1649190594979712342},
#   {'sequence': '1614275904475',
#    'price': '45858.3',
#    'size': '0.0026338',
#    'side': 'sell',
#    'time': 1649190608396294839},
#   {'sequence': '1614275904514',
#    'price': '45856.1',
#    'size': '0.00027222',
#    'side': 'sell',
#    'time': 1649190609497364998},
#   {'sequence': '1614275904567',
#    'price': '45855.2',
#    'size': '0.03458571',
#    'side': 'buy',
#    'time': 1649190613396915729},
#   {'sequence': '1614275904570',
#    'price': '45855.2',
#    'size': '0.05055682',
#    'side': 'buy',
#    'time': 1649190613418030669},
#   {'sequence': '1614275904662',
#    'price': '45860.3',
#    'size': '0.01460309',
#    'side': 'sell',
#    'time': 1649190614944723100},
#   {'sequence': '1614275904665',
#    'price': '45860.3',
#    'size': '0.01460309',
#    'side': 'sell',
#    'time': 1649190614955284219},
#   {'sequence': '1614275904672',
#    'price': '45860.3',
#    'size': '0.0241532',
#    'side': 'sell',
#    'time': 1649190615018348581},
#   {'sequence': '1614275904682',
#    'price': '45860.3',
#    'size': '0.0034538',
#    'side': 'sell',
#    'time': 1649190615134231190},
#   {'sequence': '1614275904742',
#    'price': '45853.5',
#    'size': '0.02321187',
#    'side': 'sell',
#    'time': 1649190619087711595},
#   {'sequence': '1614275904784',
#    'price': '45853.1',
#    'size': '0.00606729',
#    'side': 'sell',
#    'time': 1649190621665839794},
#   {'sequence': '1614275904787',
#    'price': '45853.1',
#    'size': '0.00606729',
#    'side': 'sell',
#    'time': 1649190621666121929},
#   {'sequence': '1614275904831',
#    'price': '45856.2',
#    'size': '0.01493334',
#    'side': 'buy',
#    'time': 1649190625696519139},
#   {'sequence': '1614275904913',
#    'price': '45852.2',
#    'size': '0.00012483',
#    'side': 'sell',
#    'time': 1649190635695809589},
#   {'sequence': '1614275905013',
#    'price': '45863.3',
#    'size': '0.01871668',
#    'side': 'buy',
#    'time': 1649190642986153109},
#   {'sequence': '1614275905018',
#    'price': '45863.3',
#    'size': '0.01008931',
#    'side': 'buy',
#    'time': 1649190643019005153},
#   {'sequence': '1614275905307',
#    'price': '45863.4',
#    'size': '0.03992327',
#    'side': 'sell',
#    'time': 1649190662263614495},
#   {'sequence': '1614275905312',
#    'price': '45863.4',
#    'size': '0.05207233',
#    'side': 'sell',
#    'time': 1649190662294585126},
#   {'sequence': '1614275905315',
#    'price': '45863.4',
#    'size': '0.00745051',
#    'side': 'sell',
#    'time': 1649190662294824479},
#   {'sequence': '1614275905570',
#    'price': '45849.5',
#    'size': '0.00020762',
#    'side': 'sell',
#    'time': 1649190675759237500},
#   {'sequence': '1614275905572',
#    'price': '45849.5',
#    'size': '0.02153167',
#    'side': 'sell',
#    'time': 1649190675759237500},
#   {'sequence': '1614275905576',
#    'price': '45849.5',
#    'size': '0.00068844',
#    'side': 'sell',
#    'time': 1649190675759576024},
#   {'sequence': '1614275905578',
#    'price': '45849.4',
#    'size': '0.00013289',
#    'side': 'sell',
#    'time': 1649190675759576024},
#   {'sequence': '1614275905718',
#    'price': '45848.9',
#    'size': '0.00327161',
#    'side': 'buy',
#    'time': 1649190684357686831},
#   {'sequence': '1614275905760',
#    'price': '45842.1',
#    'size': '0.00057487',
#    'side': 'sell',
#    'time': 1649190685225926092},
#   {'sequence': '1614275905762',
#    'price': '45842.1',
#    'size': '0.00912528',
#    'side': 'sell',
#    'time': 1649190685225926092},
#   {'sequence': '1614275905775',
#    'price': '45841.6',
#    'size': '0.00048331',
#    'side': 'sell',
#    'time': 1649190685280095202},
#   {'sequence': '1614275905777',
#    'price': '45840.5',
#    'size': '0.00006283',
#    'side': 'sell',
#    'time': 1649190685280095202},
#   {'sequence': '1614275905802',
#    'price': '45839.3',
#    'size': '0.02523318',
#    'side': 'sell',
#    'time': 1649190685374162887},
#   {'sequence': '1614275905805',
#    'price': '45839.3',
#    'size': '0.02957864',
#    'side': 'sell',
#    'time': 1649190685374397248},
#   {'sequence': '1614275905813',
#    'price': '45839.3',
#    'size': '0.03217125',
#    'side': 'sell',
#    'time': 1649190685486344380},
#   {'sequence': '1614275905823',
#    'price': '45839.3',
#    'size': '0.01245621',
#    'side': 'sell',
#    'time': 1649190685779609685},
#   {'sequence': '1614275905826',
#    'price': '45839.3',
#    'size': '0.01021263',
#    'side': 'sell',
#    'time': 1649190685779845413},
#   {'sequence': '1614275905829',
#    'price': '45839.3',
#    'size': '0.01021263',
#    'side': 'sell',
#    'time': 1649190685851787634},
#   {'sequence': '1614275905832',
#    'price': '45839.3',
#    'size': '0.01021263',
#    'side': 'sell',
#    'time': 1649190685871954623},
#   {'sequence': '1614275905914',
#    'price': '45837.7',
#    'size': '0.00003911',
#    'side': 'sell',
#    'time': 1649190689092928435},
#   {'sequence': '1614275905916',
#    'price': '45836.9',
#    'size': '0.00001665',
#    'side': 'sell',
#    'time': 1649190689092928435},
#   {'sequence': '1614275905935',
#    'price': '45835.2',
#    'size': '0.00007269',
#    'side': 'sell',
#    'time': 1649190689177837537},
#   {'sequence': '1614275905937',
#    'price': '45835',
#    'size': '0.00094555',
#    'side': 'sell',
#    'time': 1649190689177837537},
#   {'sequence': '1614275905943',
#    'price': '45834.8',
#    'size': '0.00001891',
#    'side': 'sell',
#    'time': 1649190689188420743},
#   {'sequence': '1614275905962',
#    'price': '45833.2',
#    'size': '0.00012863',
#    'side': 'sell',
#    'time': 1649190689638038864},
#   {'sequence': '1614275905964',
#    'price': '45833.2',
#    'size': '0.00312454',
#    'side': 'sell',
#    'time': 1649190689638038864},
#   {'sequence': '1614275905971',
#    'price': '45832.8',
#    'size': '0.00092641',
#    'side': 'sell',
#    'time': 1649190689729876903},
#   {'sequence': '1614275905978',
#    'price': '45831.9',
#    'size': '0.00011288',
#    'side': 'sell',
#    'time': 1649190689812209448},
#   {'sequence': '1614275905980',
#    'price': '45831.2',
#    'size': '0.00011223',
#    'side': 'sell',
#    'time': 1649190689812209448},
#   {'sequence': '1614275905990',
#    'price': '45830.3',
#    'size': '0.00003962',
#    'side': 'sell',
#    'time': 1649190689887548016},
#   {'sequence': '1614275905994',
#    'price': '45830.1',
#    'size': '0.00003834',
#    'side': 'sell',
#    'time': 1649190689887800608},
#   {'sequence': '1614275906003',
#    'price': '45829.4',
#    'size': '0.00005613',
#    'side': 'sell',
#    'time': 1649190690001555630},
#   {'sequence': '1614275906005',
#    'price': '45828.9',
#    'size': '0.00007054',
#    'side': 'sell',
#    'time': 1649190690001555630},
#   {'sequence': '1614275906045',
#    'price': '45832.9',
#    'size': '0.03826908',
#    'side': 'buy',
#    'time': 1649190690780794335},
#   {'sequence': '1614275906048',
#    'price': '45832.9',
#    'size': '0.0499992',
#    'side': 'buy',
#    'time': 1649190690853326045},
#   {'sequence': '1614275906053',
#    'price': '45832.9',
#    'size': '0.06706166',
#    'side': 'buy',
#    'time': 1649190690853648621},
#   {'sequence': '1614275906072',
#    'price': '45834.8',
#    'size': '0.03669852',
#    'side': 'buy',
#    'time': 1649190690948041479},
#   {'sequence': '1614275906393',
#    'price': '45838.2',
#    'size': '0.0101547',
#    'side': 'sell',
#    'time': 1649190696830550445},
#   {'sequence': '1614275906398',
#    'price': '45838.2',
#    'size': '0.0101547',
#    'side': 'sell',
#    'time': 1649190696851027560},
#   {'sequence': '1614275906401',
#    'price': '45838.2',
#    'size': '0.0101547',
#    'side': 'sell',
#    'time': 1649190696871916784},
#   {'sequence': '1614275906404',
#    'price': '45838.2',
#    'size': '0.00894375',
#    'side': 'sell',
#    'time': 1649190696872115352},
#   {'sequence': '1614275906407',
#    'price': '45838.2',
#    'size': '0.00859215',
#    'side': 'sell',
#    'time': 1649190696904784422},
#   {'sequence': '1614275906419',
#    'price': '45836.7',
#    'size': '0.01146746',
#    'side': 'sell',
#    'time': 1649190697049500899},
#   {'sequence': '1614275906425',
#    'price': '45836.7',
#    'size': '0.0278663',
#    'side': 'sell',
#    'time': 1649190697100966037},
#   {'sequence': '1614275906471',
#    'price': '45835.2',
#    'size': '0.00065451',
#    'side': 'buy',
#    'time': 1649190698000207286},
#   {'sequence': '1614275906558',
#    'price': '45832.4',
#    'size': '0.00789541',
#    'side': 'sell',
#    'time': 1649190705488732596},
#   {'sequence': '1614275906564',
#    'price': '45832.4',
#    'size': '0.02219945',
#    'side': 'sell',
#    'time': 1649190705636557591},
#   {'sequence': '1614275906573',
#    'price': '45832.4',
#    'size': '0.01108862',
#    'side': 'sell',
#    'time': 1649190705833389383},
#   {'sequence': '1614275906612',
#    'price': '45830',
#    'size': '0.00885917',
#    'side': 'sell',
#    'time': 1649190707966311129},
#   {'sequence': '1614275906615',
#    'price': '45830',
#    'size': '0.01013762',
#    'side': 'sell',
#    'time': 1649190707996973014},
#   {'sequence': '1614275906724',
#    'price': '45830.1',
#    'size': '0.02439888',
#    'side': 'buy',
#    'time': 1649190713777851705},
#   {'sequence': '1614275906729',
#    'price': '45830.1',
#    'size': '0.01924498',
#    'side': 'buy',
#    'time': 1649190713883141749},
#   {'sequence': '1614275906748',
#    'price': '45829.7',
#    'size': '0.02280301',
#    'side': 'buy',
#    'time': 1649190714030947836},
#   {'sequence': '1614275906751',
#    'price': '45829.7',
#    'size': '0.02280301',
#    'side': 'buy',
#    'time': 1649190714031154845},
#   {'sequence': '1614275906755',
#    'price': '45829.7',
#    'size': '0.02280301',
#    'side': 'buy',
#    'time': 1649190714115949995},
#   {'sequence': '1614275906758',
#    'price': '45829.7',
#    'size': '0.01887966',
#    'side': 'buy',
#    'time': 1649190714126821484}]}

# %% [markdown]
# # lusoft
# [Code](https://code.luasoftware.com/tutorials/cryptocurrency/binance-api-download-daily-historical-data/)

# %%
import datetime
import requests
from urllib.parse import urljoin

class BinanceException(Exception):
    def __init__(self, status_code, data=None):

        self.status_code = status_code
        if data:
            self.code = data['code']
            self.msg = data['msg']
            message = f"{status_code} [{self.code}] {self.msg}"
        else:
            self.code = None
            self.msg = None
            message = f"status_code={status_code}"

        # Python 2.x
        # super(BinanceException, self).__init__(message)
        super().__init__(message)


def download_historical_data(symbol, date):

    def download_12h(start_date, end_date):
        start_time = int(start_date.timestamp() * 1000)
        end_time = int(end_date.timestamp() * 1000)

        BINANCE_API_KEY = '...'
        # BINANCE_SECRET_KEY = '...'

        PATH = '/api/v1/klines'

        params = {
            'symbol': symbol,
            'interval': '1m',   # 1m, 3m, 5m, 15m, 30m
            'limit': 1000,       # 1000 is max, but we using 720 = 60 (minutes) * 12 (hours)
            'startTime': start_time,
            'endTime': end_time
        }

        headers = {
            'X-MBX-APIKEY': BINANCE_API_KEY
        }

        url = urljoin(self.BASE_URL, PATH)
        r = requests.get(url, headers=headers, params=params)

        if r.status_code == 200:
            return r.json()
        else:
            if r.headers['Content-Type'] == 'application/json':
                raise BinanceException(status_code=r.status_code, data=r.json())
            else:
                raise BinanceException(status_code=r.status_code)

    # start_date = datetime.datetime(2019, 7, 15)
    # 0-12h
    start_date = datetime.datetime.strptime(date, '%Y-%m-%d')
    end_date = start_date + datetime.timedelta(hours=12) - datetime.timedelta(seconds=1)
    data = download_12h(start_date, end_date)

    # 12-24h
    start_date = start_date + datetime.timedelta(hours=12)
    end_date = start_date + datetime.timedelta(hours=12) - datetime.timedelta(seconds=1)
    data.extend(download_12h(start_date, end_date))

    filename = f"{symbol}_{start_date.strftime('%Y-%m-%d')}"

    with open(f"{filename}.json", 'w') as f:
        json.dump(data, f, indent=2)

    with open(f"{filename}.csv", 'w') as f:
        for row in data:
            f.write(f"{row[1]}\n") # open price
            # f.write(f"{row[0]}, {row[1]}\n") # open time, open price
            # f.write("f{row[6]}, {row[4]}\n") # close time, close price

# %%
download_historical_data('BTCUSDT', '2019-07-15')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\MarcoP\OneDrive\Desktop\2021_FinanceJupyterTutorial\rbt\tutorial\sessione_2\tutorial1_scaricare_dati_storici.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000015?line=0'>1</a> download_historical_data('BTCUSDT', '2019-07-15')
#
# c:\Users\MarcoP\OneDrive\Desktop\2021_FinanceJupyterTutorial\rbt\tutorial\sessione_2\tutorial1_scaricare_dati_storici.ipynb Cell 10' in download_historical_data(symbol, date)
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=58'>59</a> start_date = datetime.datetime.strptime(date, '%Y-%m-%d')
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=59'>60</a> end_date = start_date + datetime.timedelta(hours=12) - datetime.timedelta(seconds=1)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=60'>61</a> data = download_12h(start_date, end_date)
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=62'>63</a> # 12-24h
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=63'>64</a> start_date = start_date + datetime.timedelta(hours=12)
#
# c:\Users\MarcoP\OneDrive\Desktop\2021_FinanceJupyterTutorial\rbt\tutorial\sessione_2\tutorial1_scaricare_dati_storici.ipynb Cell 10' in download_historical_data.<locals>.download_12h(start_date, end_date)
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=33'>34</a> params = {
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=34'>35</a>     'symbol': symbol,
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=35'>36</a>     'interval': '1m',   # 1m, 3m, 5m, 15m, 30m
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=38'>39</a>     'endTime': end_time
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=39'>40</a> }
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=41'>42</a> headers = {
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=42'>43</a>     'X-MBX-APIKEY': BINANCE_API_KEY
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=43'>44</a> }
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=45'>46</a> url = urljoin(self.BASE_URL, PATH)
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=46'>47</a> r = requests.get(url, headers=headers, params=params)
#      <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/rbt/tutorial/sessione_2/tutorial1_scaricare_dati_storici.ipynb#ch0000014?line=48'>49</a> if r.status_code == 200:
#
# NameError: name 'self' is not defined

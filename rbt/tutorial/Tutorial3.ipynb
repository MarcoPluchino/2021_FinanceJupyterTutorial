# %%
 # https://www.youtube.com/watch?v=Wd26AIfgTpA
 # https://coinmarketcap.com/api/documentation/v1/#section/Quick-Start-Guide
 # This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'2',
  'convert':'EUR'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '986464bd-ab22-418c-ad29-e3c4190bb5f8',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
import os
os.ex

# %%
def jsonname (name):
    for entry in data:
        if name == entry ['name']:
            return entry ['price']

# %%
print(data)
# Out:
# {'status': {'timestamp': '2022-03-30T18:58:42.494Z', 'error_code': 0, 'error_message': None, 'elapsed': 18, 'credit_count': 1, 'notice': None, 'total_count': 9831}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9288, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio'], 'max_supply': 21000000, 'circulating_supply': 18998300, 'total_supply': 18998300, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-03-30T18:57:00.000Z', 'quote': {'EUR': {'price': 42446.48295481912, 'volume_24h': 25977045012.017094, 'volume_change_24h': -13.4426, 'percent_change_1h': -0.69314403, 'percent_change_24h': -1.05982217, 'percent_change_7d': 10.64322477, 'percent_change_30d': 14.96231794, 'percent_change_60d': 25.16458853, 'percent_change_90d': -0.94574291, 'market_cap': 806411017120.54, 'market_cap_dominance': 41.7104, 'fully_diluted_market_cap': 891376142051.2013, 'last_updated': '2022-03-30T18:58:14.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5596, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable', 'pow', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'bnb-chain'], 'max_supply': None, 'circulating_supply': 120175868.374, 'total_supply': 120175868.374, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'last_updated': '2022-03-30T18:57:00.000Z', 'quote': {'EUR': {'price': 3057.022299071792, 'volume_24h': 14442553092.561201, 'volume_change_24h': -21.628, 'percent_change_1h': -0.52268674, 'percent_change_24h': -0.67738243, 'percent_change_7d': 13.31228066, 'percent_change_30d': 21.50180016, 'percent_change_60d': 31.54679583, 'percent_change_90d': -9.15419873, 'market_cap': 367380309429.6346, 'market_cap_dominance': 19.0042, 'fully_diluted_market_cap': 367380309429.6371, 'last_updated': '2022-03-30T18:58:14.000Z'}}}]}

# %%
print(list(filter(lambda x:x["data"]=="CZ1094",data)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\MarcoP\OneDrive\Desktop\2021_FinanceJupyterTutorial\Tutorial3.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/Tutorial3.ipynb#ch0000004?line=0'>1</a> print(list(filter(lambda x:x["data"]=="CZ1094",data)))
#
# c:\Users\MarcoP\OneDrive\Desktop\2021_FinanceJupyterTutorial\Tutorial3.ipynb Cell 5' in <lambda>(x)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MarcoP/OneDrive/Desktop/2021_FinanceJupyterTutorial/Tutorial3.ipynb#ch0000004?line=0'>1</a> print(list(filter(lambda x:x["data"]=="CZ1094",data)))
#
# TypeError: string indices must be integers

# %%
with open('data.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
# get data
a=data["data"][0]["name"]
b=data["data"][0]["quote"]["EUR"]["price"]
print(a)
print(b)
# Out:
# Bitcoin
# 40046.32212854509

# %%
# https://stackoverflow.com/questions/67562512/how-do-i-convert-coin-market-cap-api-data-from-json-to-pandas-dataframe
CoinDF = pd.json_normalize(data['data'])
CoinDF
# Out:
#      id      name symbol      slug  num_market_pairs  \
# 0     1   Bitcoin    BTC   bitcoin              8884
# 1  1027  Ethereum    ETH  ethereum              5550
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
#
#                                                 tags  max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  21000000.0
# 1  [mineable, pow, smart-contracts, ethereum, bin...         NaN
#
#    circulating_supply  total_supply  ... quote.EUR.percent_change_1h  \
# 0        1.879804e+07  1.879804e+07  ...                   -0.358889
# 1        1.172648e+08  1.172648e+08  ...                   -0.065383
#
#    quote.EUR.percent_change_24h quote.EUR.percent_change_7d  \
# 0                     -3.522781                    2.279627
# 1                     -2.732676                    1.090429
#
#    quote.EUR.percent_change_30d  quote.EUR.percent_change_60d  \
# 0                     23.194709                     41.802594
# 1                     37.215920                     69.729386
#
#    quote.EUR.percent_change_90d  quote.EUR.market_cap  \
# 0                     27.500355          7.527922e+11
# 1                     21.542730          3.115319e+11
#
#    quote.EUR.market_cap_dominance  quote.EUR.fully_diluted_market_cap  \
# 0                         43.8800                        8.409728e+11
# 1                         18.1658                        3.115319e+11
#
#      quote.EUR.last_updated
# 0  2021-08-26T14:54:13.000Z
# 1  2021-08-26T14:54:13.000Z
#
# [2 rows x 25 columns]

# %%
CoinDF.set_index("name")
# Out:
#          id symbol     slug  num_market_pairs                date_added  \
# name
# Bitcoin   1    BTC  bitcoin              8883  2013-04-28T00:00:00.000Z
#
#                                                       tags  max_supply  \
# name
# Bitcoin  [mineable, pow, sha-256, store-of-value, state...    21000000
#
#          circulating_supply  total_supply platform  ...  \
# name                                                ...
# Bitcoin            18797850      18797850     None  ...
#
#          quote.EUR.percent_change_1h quote.EUR.percent_change_24h  \
# name
# Bitcoin                    -0.453656                    -1.803933
#
#          quote.EUR.percent_change_7d  quote.EUR.percent_change_30d  \
# name
# Bitcoin                     2.985944                     25.666532
#
#          quote.EUR.percent_change_60d  quote.EUR.percent_change_90d  \
# name
# Bitcoin                     40.980908                     31.246629
#
#          quote.EUR.market_cap  quote.EUR.market_cap_dominance  \
# name
# Bitcoin          7.489138e+11                         43.8342
#
#          quote.EUR.fully_diluted_market_cap    quote.EUR.last_updated
# name
# Bitcoin                        8.366483e+11  2021-08-26T09:08:11.000Z
#
# [1 rows x 24 columns]

# %%
select = CoinDF.loc[CoinDF['name'] == 'Bitcoin']

# %%
pd.json_normalize(data['data'])
# Out:
#      id      name symbol      slug  num_market_pairs  \
# 0     1   Bitcoin    BTC   bitcoin              8884
# 1  1027  Ethereum    ETH  ethereum              5550
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
#
#                                                 tags  max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...  21000000.0
# 1  [mineable, pow, smart-contracts, ethereum, bin...         NaN
#
#    circulating_supply  total_supply  ... quote.EUR.percent_change_1h  \
# 0        1.879804e+07  1.879804e+07  ...                   -0.358889
# 1        1.172648e+08  1.172648e+08  ...                   -0.065383
#
#    quote.EUR.percent_change_24h quote.EUR.percent_change_7d  \
# 0                     -3.522781                    2.279627
# 1                     -2.732676                    1.090429
#
#    quote.EUR.percent_change_30d  quote.EUR.percent_change_60d  \
# 0                     23.194709                     41.802594
# 1                     37.215920                     69.729386
#
#    quote.EUR.percent_change_90d  quote.EUR.market_cap  \
# 0                     27.500355          7.527922e+11
# 1                     21.542730          3.115319e+11
#
#    quote.EUR.market_cap_dominance  quote.EUR.fully_diluted_market_cap  \
# 0                         43.8800                        8.409728e+11
# 1                         18.1658                        3.115319e+11
#
#      quote.EUR.last_updated
# 0  2021-08-26T14:54:13.000Z
# 1  2021-08-26T14:54:13.000Z
#
# [2 rows x 25 columns]
